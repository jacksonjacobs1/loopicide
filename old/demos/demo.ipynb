# %%
import numpy as np
import matplotlib.pyplot as plt
from loopicide import remove_loops

# %%
problem_example = np.array([(0,0), (0,-1), (0,-3), (1,-1), (1,-3), (2,-2), (-1,-2),(-3,-2),(-2, -3), (-2, 0)])

# %%
# %%timeit
problem_example_no_loops = remove_loops(problem_example)
# Out:
# 937 μs ± 13.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
plt.plot(problem_example[:,0], problem_example[:,1], '--b', marker='o', label='Original')
plt.plot(problem_example_no_loops[:,0], problem_example_no_loops[:,1], '-r', marker='.', label='No loops')
plt.legend()
plt.show()

# %%
plt.plot(problem_example[:,0], problem_example[:,1], '--b', marker='o', label='Original')
plt.plot(problem_example_no_loops[:,0], problem_example_no_loops[:,1], '-r', marker='.', label='No loops')
plt.legend()
plt.show()

# %%
problem_example2 = np.array([(-56.8217793676305, -8.88299365847671), (-113.643558735261, -17.7659873169534),
(-56.6527353669234, -25.4905092205507), (-109.059870307362, -1.80265591606324),
(-65.6069009172882, -39.4783992800045), (-96.4819575546674,  9.04327695318884),
(-65.6069009172882, -39.4783992800045), (-109.059870307362, -1.80265591606324),
(-56.6527353669234, -25.4905092205507), (-94.6466176124818, -20.3408279514859),
(-151.468396980112, -29.2238216099626)])

problem_example2_no_loops = remove_loops(problem_example2)
plt.plot(problem_example2[:,0], problem_example2[:,1], '--b', marker='o', label='Original')
plt.plot(problem_example2_no_loops[:,0], problem_example2_no_loops[:,1], '-r', marker='.', label='No loops')
plt.legend()
plt.show()
